# %% [markdown]
# Download & concat spring documentation websites

# %%
import requests
import os
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from markdownify import markdownify as md
import time

# Selectors provided
NAV_SELECTOR = "a.nav-link"
CONTENT_SELECTOR = "article.doc"

def get_soup(url):
    """Fetches a URL and returns a BeautifulSoup object."""
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def extract_nav_links(base_url, soup):
    """Extracts all navigation links using the specific selector."""
    links = []
    # select all 'a' tags with class 'nav-link'
    nav_elements = soup.select(NAV_SELECTOR)

    for nav in nav_elements:
        href = nav.get('href')
        if href:
            # Handle relative URLs by joining them with the base URL
            full_url = urljoin(base_url, href)
            # Remove anchor fragments (e.g., #section-1) to avoid duplicates
            clean_url = full_url.split('#')[0]
            if clean_url not in links:
                links.append(clean_url)

    return links

def extract_content(soup):
    """Extracts content from article.doc and converts to Markdown."""
    content_div = soup.select_one(CONTENT_SELECTOR)

    if content_div:
        # specific cleaning: remove permalinks or navigation buttons if necessary
        # Convert HTML to Markdown
        return md(str(content_div), heading_style="ATX")
    else:
        return None

def process_website(base_url, output_file):
    if os.path.exists(output_file):
        print(f"WARNING: The file '{output_file}' already exists.")
        return

    main_soup = get_soup(base_url)

    if not main_soup:
        raise Exception("Error fetching main page. Check BASE_URL.")
    # 2. Extract all page links

    page_links = extract_nav_links(base_url, main_soup)
    print(f"Found {len(page_links)} pages to process.")

    # 3. Iterate through links and append content to output_file
    with open(output_file, "w", encoding="utf-8") as f:
        # Add a title to the document
        f.write(f"# Spring Boot Documentation\n\nSource: {base_url}\n\n---\n\n")

        for i, link in enumerate(page_links):
            print(f"Processing ({i+1}/{len(page_links)}): {link}")

            page_soup = get_soup(link)
            if page_soup:
                markdown_content = extract_content(page_soup)

                if markdown_content:
                    f.write(markdown_content)
                    f.write("\n\n---\n\n") # Separator between pages
                else:
                    print(f"Warning: No content found for selector '{CONTENT_SELECTOR}' on {link}")

            # Be polite to the server
            time.sleep(0.5)

    print(f"\nDone! Documentation saved to {output_file}")

# %%
urls = {
    "spring-security.md": "https://docs.spring.io/spring-security/reference/index.html",
    "spring-authorization-server.md": "https://docs.spring.io/spring-authorization-server/reference/overview.html",
    "spring-boot.md": "https://docs.spring.io/spring-boot/index.html",
    "spring-graphql.md": "https://docs.spring.io/spring-graphql/reference/index.html",
    "spring-framework.md": "https://docs.spring.io/spring-framework/reference/overview.html",
    "spring-data-commons.md": "https://docs.spring.io/spring-data/commons/reference/index.html",
    "spring-data-jpa.md": "https://docs.spring.io/spring-data/jpa/reference/",
    "spring-amqp.md": "https://docs.spring.io/spring-amqp/reference/",
    "spring-integration.md": "https://docs.spring.io/spring-integration/reference/"
}

for output_file, base_url in urls.items():
    process_website(base_url, f"data/ephemeral/spring-doc/{output_file}")
# Out:
# WARNING: The file 'temp/spring-security.md' already exists.
# WARNING: The file 'temp/spring-authorization-server.md' already exists.
# WARNING: The file 'temp/spring-boot.md' already exists.
# WARNING: The file 'temp/spring-graphql.md' already exists.
# WARNING: The file 'temp/spring-framework.md' already exists.
# WARNING: The file 'temp/spring-data-commons.md' already exists.
# WARNING: The file 'temp/spring-data-jpa.md' already exists.
# WARNING: The file 'temp/spring-amqp.md' already exists.
# Found 280 pages to process.
# Processing (1/280): https://docs.spring.io/spring-integration/reference/index.html
# Processing (2/280): https://docs.spring.io/spring-integration/reference/preface.html
# Processing (3/280): https://docs.spring.io/spring-integration/reference/whats-new.html
# Processing (4/280): https://docs.spring.io/spring-integration/reference/overview.html
# Processing (5/280): https://docs.spring.io/spring-integration/reference/core.html
# Processing (6/280): https://docs.spring.io/spring-integration/reference/channel.html
# Processing (7/280): https://docs.spring.io/spring-integration/reference/channel/interfaces.html
# Processing (8/280): https://docs.spring.io/spring-integration/reference/channel/implementations.html
# Processing (9/280): https://docs.spring.io/spring-integration/reference/channel/interceptors.html
# Processing (10/280): https://docs.spring.io/spring-integration/reference/channel/template.html
# Processing (11/280): https://docs.spring.io/spring-integration/reference/channel/configuration.html
# Processing (12/280): https://docs.spring.io/spring-integration/reference/channel/special-channels.html
# Processing (13/280): https://docs.spring.io/spring-integration/reference/polling-consumer.html
# Processing (14/280): https://docs.spring.io/spring-integration/reference/channel-adapter.html
# Processing (15/280): https://docs.spring.io/spring-integration/reference/bridge.html
# Processing (16/280): https://docs.spring.io/spring-integration/reference/message.html
# Processing (17/280): https://docs.spring.io/spring-integration/reference/message-routing.html
# Processing (18/280): https://docs.spring.io/spring-integration/reference/router.html
# Processing (19/280): https://docs.spring.io/spring-integration/reference/router/overview.html
# Processing (20/280): https://docs.spring.io/spring-integration/reference/router/common-parameters.html
# Processing (21/280): https://docs.spring.io/spring-integration/reference/router/implementations.html
# Processing (22/280): https://docs.spring.io/spring-integration/reference/router/namespace.html
# Processing (23/280): https://docs.spring.io/spring-integration/reference/router/spel.html
# Processing (24/280): https://docs.spring.io/spring-integration/reference/router/annotation.html
# Processing (25/280): https://docs.spring.io/spring-integration/reference/router/dynamic-routers.html
# Processing (26/280): https://docs.spring.io/spring-integration/reference/router/routing-slip.html
# Processing (27/280): https://docs.spring.io/spring-integration/reference/router/process-manager.html
# Processing (28/280): https://docs.spring.io/spring-integration/reference/filter.html
# Processing (29/280): https://docs.spring.io/spring-integration/reference/splitter.html
# Processing (30/280): https://docs.spring.io/spring-integration/reference/aggregator.html
# Processing (31/280): https://docs.spring.io/spring-integration/reference/resequencer.html
# Processing (32/280): https://docs.spring.io/spring-integration/reference/chain.html
# Processing (33/280): https://docs.spring.io/spring-integration/reference/scatter-gather.html
# Processing (34/280): https://docs.spring.io/spring-integration/reference/barrier.html
# Processing (35/280): https://docs.spring.io/spring-integration/reference/message-transformation.html
# Processing (36/280): https://docs.spring.io/spring-integration/reference/transformer.html
# Processing (37/280): https://docs.spring.io/spring-integration/reference/content-enrichment.html
# Processing (38/280): https://docs.spring.io/spring-integration/reference/claim-check.html
# Processing (39/280): https://docs.spring.io/spring-integration/reference/codec.html
# Processing (40/280): https://docs.spring.io/spring-integration/reference/messaging-endpoints.html
# Processing (41/280): https://docs.spring.io/spring-integration/reference/endpoint.html
# Processing (42/280): https://docs.spring.io/spring-integration/reference/endpoint-roles.html
# Processing (43/280): https://docs.spring.io/spring-integration/reference/leadership-event-handling.html
# Processing (44/280): https://docs.spring.io/spring-integration/reference/gateway.html
# Processing (45/280): https://docs.spring.io/spring-integration/reference/service-activator.html
# Processing (46/280): https://docs.spring.io/spring-integration/reference/delayer.html
# Processing (47/280): https://docs.spring.io/spring-integration/reference/scripting.html
# Processing (48/280): https://docs.spring.io/spring-integration/reference/groovy.html
# Processing (49/280): https://docs.spring.io/spring-integration/reference/handler-advice.html
# Processing (50/280): https://docs.spring.io/spring-integration/reference/handler-advice/classes.html
# Processing (51/280): https://docs.spring.io/spring-integration/reference/handler-advice/reactive.html
# Processing (52/280): https://docs.spring.io/spring-integration/reference/handler-advice/context-holder.html
# Processing (53/280): https://docs.spring.io/spring-integration/reference/handler-advice/custom.html
# Processing (54/280): https://docs.spring.io/spring-integration/reference/handler-advice/other.html
# Processing (55/280): https://docs.spring.io/spring-integration/reference/handler-advice/handle-message.html
# Processing (56/280): https://docs.spring.io/spring-integration/reference/handler-advice/tx-handle-message.html
# Processing (57/280): https://docs.spring.io/spring-integration/reference/handler-advice/advising-filters.html
# Processing (58/280): https://docs.spring.io/spring-integration/reference/handler-advice/advising-with-annotations.html
# Processing (59/280): https://docs.spring.io/spring-integration/reference/handler-advice/order.html
# Processing (60/280): https://docs.spring.io/spring-integration/reference/handler-advice/advised-properties.html
# Processing (61/280): https://docs.spring.io/spring-integration/reference/handler-advice/idempotent-receiver.html
# Processing (62/280): https://docs.spring.io/spring-integration/reference/logging-adapter.html
# Processing (63/280): https://docs.spring.io/spring-integration/reference/functions-support.html
# Processing (64/280): https://docs.spring.io/spring-integration/reference/kotlin-functions.html
# Processing (65/280): https://docs.spring.io/spring-integration/reference/dsl.html
# Processing (66/280): https://docs.spring.io/spring-integration/reference/dsl/java-basics.html
# Processing (67/280): https://docs.spring.io/spring-integration/reference/dsl/java-channels.html
# Processing (68/280): https://docs.spring.io/spring-integration/reference/dsl/java-pollers.html
# Processing (69/280): https://docs.spring.io/spring-integration/reference/dsl/java-reactive.html
# Processing (70/280): https://docs.spring.io/spring-integration/reference/dsl/java-endpoints.html
# Processing (71/280): https://docs.spring.io/spring-integration/reference/dsl/java-transformers.html
# Processing (72/280): https://docs.spring.io/spring-integration/reference/dsl/java-inbound-adapters.html
# Processing (73/280): https://docs.spring.io/spring-integration/reference/dsl/java-routers.html
# Processing (74/280): https://docs.spring.io/spring-integration/reference/dsl/java-splitters.html
# Processing (75/280): https://docs.spring.io/spring-integration/reference/dsl/java-aggregators.html
# Processing (76/280): https://docs.spring.io/spring-integration/reference/dsl/java-handle.html
# Processing (77/280): https://docs.spring.io/spring-integration/reference/dsl/java-gateway.html
# Processing (78/280): https://docs.spring.io/spring-integration/reference/dsl/java-log.html
# Processing (79/280): https://docs.spring.io/spring-integration/reference/dsl/java-intercept.html
# Processing (80/280): https://docs.spring.io/spring-integration/reference/dsl/java-wiretap.html
# Processing (81/280): https://docs.spring.io/spring-integration/reference/dsl/java-flows.html
# Processing (82/280): https://docs.spring.io/spring-integration/reference/dsl/java-function-expression.html
# Processing (83/280): https://docs.spring.io/spring-integration/reference/dsl/java-subflows.html
# Processing (84/280): https://docs.spring.io/spring-integration/reference/dsl/java-protocol-adapters.html
# Processing (85/280): https://docs.spring.io/spring-integration/reference/dsl/java-flow-adapter.html
# Processing (86/280): https://docs.spring.io/spring-integration/reference/dsl/java-runtime-flows.html
# Processing (87/280): https://docs.spring.io/spring-integration/reference/dsl/integration-flow-as-gateway.html
# Processing (88/280): https://docs.spring.io/spring-integration/reference/dsl/java-extensions.html
# Processing (89/280): https://docs.spring.io/spring-integration/reference/dsl/integration-flows-composition.html
# Processing (90/280): https://docs.spring.io/spring-integration/reference/groovy-dsl.html
# Processing (91/280): https://docs.spring.io/spring-integration/reference/kotlin-dsl.html
# Processing (92/280): https://docs.spring.io/spring-integration/reference/system-management.html
# Processing (93/280): https://docs.spring.io/spring-integration/reference/metrics.html
# Processing (94/280): https://docs.spring.io/spring-integration/reference/message-history.html
# Processing (95/280): https://docs.spring.io/spring-integration/reference/message-store.html
# Processing (96/280): https://docs.spring.io/spring-integration/reference/meta-data-store.html
# Processing (97/280): https://docs.spring.io/spring-integration/reference/distributed-locks.html
# Processing (98/280): https://docs.spring.io/spring-integration/reference/control-bus.html
# Processing (99/280): https://docs.spring.io/spring-integration/reference/shutdown.html
# Processing (100/280): https://docs.spring.io/spring-integration/reference/graph.html
# Processing (101/280): https://docs.spring.io/spring-integration/reference/integration-graph-controller.html
# Processing (102/280): https://docs.spring.io/spring-integration/reference/reactive-streams.html
# Processing (103/280): https://docs.spring.io/spring-integration/reference/native-aot.html
# Processing (104/280): https://docs.spring.io/spring-integration/reference/endpoint-summary.html
# Processing (105/280): https://docs.spring.io/spring-integration/reference/amqp.html
# Processing (106/280): https://docs.spring.io/spring-integration/reference/amqp/inbound-channel-adapter.html
# Processing (107/280): https://docs.spring.io/spring-integration/reference/amqp/polled-inbound-channel-adapter.html
# Processing (108/280): https://docs.spring.io/spring-integration/reference/amqp/inbound-gateway.html
# Processing (109/280): https://docs.spring.io/spring-integration/reference/amqp/inbound-ack.html
# Processing (110/280): https://docs.spring.io/spring-integration/reference/amqp/outbound-endpoints.html
# Processing (111/280): https://docs.spring.io/spring-integration/reference/amqp/outbound-channel-adapter.html
# Processing (112/280): https://docs.spring.io/spring-integration/reference/amqp/outbound-gateway.html
# Processing (113/280): https://docs.spring.io/spring-integration/reference/amqp/async-outbound-gateway.html
# Processing (114/280): https://docs.spring.io/spring-integration/reference/amqp/alternative-confirms-returns.html
# Processing (115/280): https://docs.spring.io/spring-integration/reference/amqp/conversion-inbound.html
# Processing (116/280): https://docs.spring.io/spring-integration/reference/amqp/content-type-conversion-outbound.html
# Processing (117/280): https://docs.spring.io/spring-integration/reference/amqp/user-id.html
# Processing (118/280): https://docs.spring.io/spring-integration/reference/amqp/delay.html
# Processing (119/280): https://docs.spring.io/spring-integration/reference/amqp/channels.html
# Processing (120/280): https://docs.spring.io/spring-integration/reference/amqp/message-headers.html
# Processing (121/280): https://docs.spring.io/spring-integration/reference/amqp/strict-ordering.html
# Processing (122/280): https://docs.spring.io/spring-integration/reference/amqp/samples.html
# Processing (123/280): https://docs.spring.io/spring-integration/reference/amqp/rmq-streams.html
# Processing (124/280): https://docs.spring.io/spring-integration/reference/amqp/amqp-1.0.html
# Processing (125/280): https://docs.spring.io/spring-integration/reference/camel.html
# Processing (126/280): https://docs.spring.io/spring-integration/reference/cassandra.html
# Processing (127/280): https://docs.spring.io/spring-integration/reference/debezium.html
# Processing (128/280): https://docs.spring.io/spring-integration/reference/event.html
# Processing (129/280): https://docs.spring.io/spring-integration/reference/feed.html
# Processing (130/280): https://docs.spring.io/spring-integration/reference/file.html
# Processing (131/280): https://docs.spring.io/spring-integration/reference/file/reading.html
# Processing (132/280): https://docs.spring.io/spring-integration/reference/file/writing.html
# Processing (133/280): https://docs.spring.io/spring-integration/reference/file/transforming.html
# Processing (134/280): https://docs.spring.io/spring-integration/reference/file/splitter.html
# Processing (135/280): https://docs.spring.io/spring-integration/reference/file/aggregator.html
# Processing (136/280): https://docs.spring.io/spring-integration/reference/file/remote-persistent-flf.html
# Processing (137/280): https://docs.spring.io/spring-integration/reference/ftp.html
# Processing (138/280): https://docs.spring.io/spring-integration/reference/ftp/session-factory.html
# Processing (139/280): https://docs.spring.io/spring-integration/reference/ftp/advanced-configuration.html
# Processing (140/280): https://docs.spring.io/spring-integration/reference/ftp/dsf.html
# Processing (141/280): https://docs.spring.io/spring-integration/reference/ftp/inbound.html
# Processing (142/280): https://docs.spring.io/spring-integration/reference/ftp/streaming.html
# Processing (143/280): https://docs.spring.io/spring-integration/reference/ftp/rotating-server-advice.html
# Processing (144/280): https://docs.spring.io/spring-integration/reference/ftp/max-fetch.html
# Processing (145/280): https://docs.spring.io/spring-integration/reference/ftp/outbound.html
# Processing (146/280): https://docs.spring.io/spring-integration/reference/ftp/outbound-gateway.html
# Processing (147/280): https://docs.spring.io/spring-integration/reference/ftp/session-caching.html
# Processing (148/280): https://docs.spring.io/spring-integration/reference/ftp/rft.html
# Processing (149/280): https://docs.spring.io/spring-integration/reference/ftp/session-callback.html
# Processing (150/280): https://docs.spring.io/spring-integration/reference/ftp/server-events.html
# Processing (151/280): https://docs.spring.io/spring-integration/reference/ftp/remote-file-info.html
# Processing (152/280): https://docs.spring.io/spring-integration/reference/graphql.html
# Processing (153/280): https://docs.spring.io/spring-integration/reference/hazelcast.html
# Processing (154/280): https://docs.spring.io/spring-integration/reference/http.html
# Processing (155/280): https://docs.spring.io/spring-integration/reference/http/inbound.html
# Processing (156/280): https://docs.spring.io/spring-integration/reference/http/outbound.html
# Processing (157/280): https://docs.spring.io/spring-integration/reference/http/namespace.html
# Processing (158/280): https://docs.spring.io/spring-integration/reference/http/java-config.html
# Processing (159/280): https://docs.spring.io/spring-integration/reference/http/timeout.html
# Processing (160/280): https://docs.spring.io/spring-integration/reference/http/proxy.html
# Processing (161/280): https://docs.spring.io/spring-integration/reference/http/header-mapping.html
# Processing (162/280): https://docs.spring.io/spring-integration/reference/http/int-graph-controller.html
# Processing (163/280): https://docs.spring.io/spring-integration/reference/http/control-bus-controller.html
# Processing (164/280): https://docs.spring.io/spring-integration/reference/http/samples.html
# Processing (165/280): https://docs.spring.io/spring-integration/reference/ip.html
# Processing (166/280): https://docs.spring.io/spring-integration/reference/ip/intro.html
# Processing (167/280): https://docs.spring.io/spring-integration/reference/ip/udp-adapters.html
# Processing (168/280): https://docs.spring.io/spring-integration/reference/ip/tcp-connection-factories.html
# Processing (169/280): https://docs.spring.io/spring-integration/reference/ip/testing-connections.html
# Processing (170/280): https://docs.spring.io/spring-integration/reference/ip/interceptors.html
# Processing (171/280): https://docs.spring.io/spring-integration/reference/ip/tcp-events.html
# Processing (172/280): https://docs.spring.io/spring-integration/reference/ip/tcp-adapters.html
# Processing (173/280): https://docs.spring.io/spring-integration/reference/ip/tcp-gateways.html
# Processing (174/280): https://docs.spring.io/spring-integration/reference/ip/correlation.html
# Processing (175/280): https://docs.spring.io/spring-integration/reference/ip/note-nio.html
# Processing (176/280): https://docs.spring.io/spring-integration/reference/ip/ssl-tls.html
# Processing (177/280): https://docs.spring.io/spring-integration/reference/ip/tcp-advanced-techniques.html
# Processing (178/280): https://docs.spring.io/spring-integration/reference/ip/endpoint-reference.html
# Processing (179/280): https://docs.spring.io/spring-integration/reference/ip/msg-headers.html
# Processing (180/280): https://docs.spring.io/spring-integration/reference/ip/annotation.html
# Processing (181/280): https://docs.spring.io/spring-integration/reference/ip/dsl.html
# Processing (182/280): https://docs.spring.io/spring-integration/reference/jdbc.html
# Processing (183/280): https://docs.spring.io/spring-integration/reference/jdbc/inbound-channel-adapter.html
# Processing (184/280): https://docs.spring.io/spring-integration/reference/jdbc/outbound-channel-adapter.html
# Processing (185/280): https://docs.spring.io/spring-integration/reference/jdbc/outbound-gateway.html
# Processing (186/280): https://docs.spring.io/spring-integration/reference/jdbc/message-store.html
# Processing (187/280): https://docs.spring.io/spring-integration/reference/jdbc/message-store-json.html
# Processing (188/280): https://docs.spring.io/spring-integration/reference/jdbc/stored-procedures.html
# Processing (189/280): https://docs.spring.io/spring-integration/reference/jdbc/dsl.html
# Processing (190/280): https://docs.spring.io/spring-integration/reference/jdbc/lock-registry.html
# Processing (191/280): https://docs.spring.io/spring-integration/reference/jdbc/metadata-store.html
# Processing (192/280): https://docs.spring.io/spring-integration/reference/jpa.html
# Processing (193/280): https://docs.spring.io/spring-integration/reference/jpa/functionality.html
# Processing (194/280): https://docs.spring.io/spring-integration/reference/jpa/supported-persistence-providers.html
# Processing (195/280): https://docs.spring.io/spring-integration/reference/jpa/java-implementation.html
# Processing (196/280): https://docs.spring.io/spring-integration/reference/jpa/namespace-support.html
# Processing (197/280): https://docs.spring.io/spring-integration/reference/jpa/inbound-channel-adapter.html
# Processing (198/280): https://docs.spring.io/spring-integration/reference/jpa/outbound-channel-adapter.html
# Processing (199/280): https://docs.spring.io/spring-integration/reference/jpa/outbound-gateways.html
# Processing (200/280): https://docs.spring.io/spring-integration/reference/jms.html
# Processing (201/280): https://docs.spring.io/spring-integration/reference/jmx.html
# Processing (202/280): https://docs.spring.io/spring-integration/reference/kafka.html
# Processing (203/280): https://docs.spring.io/spring-integration/reference/mail.html
# Processing (204/280): https://docs.spring.io/spring-integration/reference/mongodb.html
# Processing (205/280): https://docs.spring.io/spring-integration/reference/mqtt.html
# Processing (206/280): https://docs.spring.io/spring-integration/reference/r2dbc.html
# Processing (207/280): https://docs.spring.io/spring-integration/reference/redis.html
# Processing (208/280): https://docs.spring.io/spring-integration/reference/resource.html
# Processing (209/280): https://docs.spring.io/spring-integration/reference/rsocket.html
# Processing (210/280): https://docs.spring.io/spring-integration/reference/sftp.html
# Processing (211/280): https://docs.spring.io/spring-integration/reference/sftp/session-factory.html
# Processing (212/280): https://docs.spring.io/spring-integration/reference/sftp/dsf.html
# Processing (213/280): https://docs.spring.io/spring-integration/reference/sftp/session-caching.html
# Processing (214/280): https://docs.spring.io/spring-integration/reference/sftp/rft.html
# Processing (215/280): https://docs.spring.io/spring-integration/reference/sftp/inbound.html
# Processing (216/280): https://docs.spring.io/spring-integration/reference/sftp/streaming.html
# Processing (217/280): https://docs.spring.io/spring-integration/reference/sftp/rotating-server-advice.html
# Processing (218/280): https://docs.spring.io/spring-integration/reference/sftp/max-fetch.html
# Processing (219/280): https://docs.spring.io/spring-integration/reference/sftp/outbound.html
# Processing (220/280): https://docs.spring.io/spring-integration/reference/sftp/outbound-gateway.html
# Processing (221/280): https://docs.spring.io/spring-integration/reference/sftp/session-callback.html
# Processing (222/280): https://docs.spring.io/spring-integration/reference/sftp/server-events.html
# Processing (223/280): https://docs.spring.io/spring-integration/reference/sftp/remote-file-info.html
# Processing (224/280): https://docs.spring.io/spring-integration/reference/smb.html
# Processing (225/280): https://docs.spring.io/spring-integration/reference/stomp.html
# Processing (226/280): https://docs.spring.io/spring-integration/reference/stream.html
# Processing (227/280): https://docs.spring.io/spring-integration/reference/syslog.html
# Processing (228/280): https://docs.spring.io/spring-integration/reference/webflux.html
# Processing (229/280): https://docs.spring.io/spring-integration/reference/web-sockets.html
# Processing (230/280): https://docs.spring.io/spring-integration/reference/ws.html
# Processing (231/280): https://docs.spring.io/spring-integration/reference/xml.html
# Processing (232/280): https://docs.spring.io/spring-integration/reference/xml/xpath-namespace-support.html
# Processing (233/280): https://docs.spring.io/spring-integration/reference/xml/transformation.html
# Processing (234/280): https://docs.spring.io/spring-integration/reference/xml/xpath-transformer.html
# Processing (235/280): https://docs.spring.io/spring-integration/reference/xml/xpath-splitting.html
# Processing (236/280): https://docs.spring.io/spring-integration/reference/xml/xpath-routing.html
# Processing (237/280): https://docs.spring.io/spring-integration/reference/xml/xpath-header-enricher.html
# Processing (238/280): https://docs.spring.io/spring-integration/reference/xml/xpath-filter.html
# Processing (239/280): https://docs.spring.io/spring-integration/reference/xml/xpath-spel-function.html
# Processing (240/280): https://docs.spring.io/spring-integration/reference/xml/validating-filter.html
# Processing (241/280): https://docs.spring.io/spring-integration/reference/xmpp.html
# Processing (242/280): https://docs.spring.io/spring-integration/reference/zeromq.html
# Processing (243/280): https://docs.spring.io/spring-integration/reference/zip.html
# Processing (244/280): https://docs.spring.io/spring-integration/reference/zookeeper.html
# Processing (245/280): https://docs.spring.io/spring-integration/reference/error-handling.html
# Processing (246/280): https://docs.spring.io/spring-integration/reference/spel.html
# Processing (247/280): https://docs.spring.io/spring-integration/reference/message-publishing.html
# Processing (248/280): https://docs.spring.io/spring-integration/reference/transactions.html
# Processing (249/280): https://docs.spring.io/spring-integration/reference/security.html
# Processing (250/280): https://docs.spring.io/spring-integration/reference/configuration.html
# Processing (251/280): https://docs.spring.io/spring-integration/reference/configuration/namespace.html
# Processing (252/280): https://docs.spring.io/spring-integration/reference/configuration/namespace-taskscheduler.html
# Processing (253/280): https://docs.spring.io/spring-integration/reference/configuration/global-properties.html
# Processing (254/280): https://docs.spring.io/spring-integration/reference/configuration/annotations.html
# Processing (255/280): https://docs.spring.io/spring-integration/reference/configuration/meta-annotations.html
# Processing (256/280): https://docs.spring.io/spring-integration/reference/configuration/message-mapping-rules.html
# Processing (257/280): https://docs.spring.io/spring-integration/reference/testing.html
# Processing (258/280): https://docs.spring.io/spring-integration/reference/samples.html
# Processing (259/280): https://docs.spring.io/spring-integration/reference/resources.html
# Processing (260/280): https://docs.spring.io/spring-integration/reference/history.html
# Processing (261/280): https://docs.spring.io/spring-integration/reference/changes-6.4-6.5.html
# Processing (262/280): https://docs.spring.io/spring-integration/reference/changes-6.3-6.4.html
# Processing (263/280): https://docs.spring.io/spring-integration/reference/changes-6.2-6.3.html
# Processing (264/280): https://docs.spring.io/spring-integration/reference/changes-6.1-6.2.html
# Processing (265/280): https://docs.spring.io/spring-integration/reference/changes-6.0-6.1.html
# Processing (266/280): https://docs.spring.io/spring-integration/reference/changes-5.5-6.0.html
# Processing (267/280): https://docs.spring.io/spring-integration/reference/changes-5.4-5.5.html
# Processing (268/280): https://docs.spring.io/spring-integration/reference/changes-5.3-5.4.html
# Processing (269/280): https://docs.spring.io/spring-integration/reference/changes-5.2-5.3.html
# Processing (270/280): https://docs.spring.io/spring-integration/reference/changes-5.1-5.2.html
# Processing (271/280): https://docs.spring.io/spring-integration/reference/changes-5.0-5.1.html
# Processing (272/280): https://docs.spring.io/spring-integration/reference/changes-4.3-5.0.html
# Processing (273/280): https://docs.spring.io/spring-integration/reference/changes-4.2-4.3.html
# Processing (274/280): https://docs.spring.io/spring-integration/reference/changes-4.1-4.2.html
# Processing (275/280): https://docs.spring.io/spring-integration/reference/changes-4.0-4.1.html
# Processing (276/280): https://docs.spring.io/spring-integration/reference/changes-3.0-4.0.html
# Processing (277/280): https://docs.spring.io/spring-integration/reference/changes-2.2-3.0.html
# Processing (278/280): https://docs.spring.io/spring-integration/reference/changes-2.1-2.2.html
# Processing (279/280): https://docs.spring.io/spring-integration/reference/changes-2.0-2.1.html
# Processing (280/280): https://docs.spring.io/spring-integration/reference/changes-1.0-2.0.html
#
# Done! Documentation saved to temp/spring-integration.md
